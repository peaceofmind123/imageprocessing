# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def negative(M):
    
    return np.max(M) - M

# %%
genius = plt.imread('./imgs/einstein.tif')
plt.imshow(genius, cmap='gray')

# %%
neg = negative(genius)
neg
# Out:
# array([[189, 191, 194, ..., 178, 173, 171],
#        [191, 193, 196, ..., 174, 171, 169],
#        [194, 196, 199, ..., 178, 175, 173],
#        ...,
#        [206, 206, 207, ..., 204, 201, 199],
#        [203, 203, 204, ..., 202, 199, 197],
#        [199, 199, 201, ..., 201, 198, 196]], dtype=uint8)

# %%
plt.imshow(neg, cmap='gray')
