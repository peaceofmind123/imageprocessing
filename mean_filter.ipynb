# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import scipy.signal as ss

# %%
meanF = np.ones((9,9)) * 1/81

# %%
noisy = plt.imread('./imgs/noisy_g.tif')
plt.imshow(noisy, cmap='gray')

# %%
avgd = ss.correlate2d(noisy, meanF, mode='same',boundary='wrap')

# %%
plt.imshow(avgd, cmap='gray')
